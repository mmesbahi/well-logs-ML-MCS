# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# Set visual style
sns.set_style("whitegrid")

df = pd.read_csv('../dataset/15_9-23.csv') 


print(f"Data Loaded. Shape: {df.shape}")
# Out:
# Data Loaded. Shape: (11063, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11063 entries, 0 to 11062
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   WELL                               11063 non-null  object
#  1   DEPTH_MD                           11063 non-null  float64
#  2   X_LOC                              11063 non-null  float64
#  3   Y_LOC                              11063 non-null  float64
#  4   Z_LOC                              11063 non-null  float64
#  5   GROUP                              11063 non-null  object
#  6   FORMATION                          11063 non-null  object
#  7   CALI                               11063 non-null  float64
#  8   RMED                               11009 non-null  float64
#  9   RDEP                               11063 non-null  float64
#  10  RHOB                               11009 non-null  float64
# ...

# %%
df=df.drop(['RSHA','SP','SGR','MUDWEIGHT','RMIC','RXO'],axis=1)

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10302 entries, 54 to 10940
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   WELL                               10302 non-null  object
#  1   DEPTH_MD                           10302 non-null  float64
#  2   X_LOC                              10302 non-null  float64
#  3   Y_LOC                              10302 non-null  float64
#  4   Z_LOC                              10302 non-null  float64
#  5   GROUP                              10302 non-null  object
#  6   FORMATION                          10302 non-null  object
#  7   CALI                               10302 non-null  float64
#  8   RMED                               10302 non-null  float64
#  9   RDEP                               10302 non-null  float64
#  10  RHOB                               10302 non-null  float64
# ...

# %%
plt.figure(figsize=(14, 5))

# Plot 1: Raw Distribution
plt.subplot(1, 2, 1)
sns.histplot(df['RDEP'].dropna(), kde=True, color='brown')
plt.title("Raw Resistivity (RDEP) Distribution")
plt.xlabel("Ohm.m")

# Plot 2: Log10 Distribution
plt.subplot(1, 2, 2)
# We use log10 (handling potential zeros slightly)
log_rdep = np.log10(df['RDEP'].dropna())
sns.histplot(log_rdep, kde=True, color='green')
plt.title("Log10(Resistivity) Distribution")
plt.xlabel("Log10(Ohm.m)")

plt.show()

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=[np.number]).copy()

# Apply Log to RDEP for the correlation check (since we will model the log)
numeric_df['log_RDEP'] = np.log10(numeric_df['RDEP'])
# Drop the raw RDEP so it doesn't correlate with itself
numeric_df = numeric_df.drop(columns=['RDEP'])

# Calculate Matrix
corr_matrix = numeric_df.corr()

# Visualize
plt.figure(figsize=(12, 10))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix[['log_RDEP']].sort_values(by='log_RDEP', ascending=False),
            annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation with Target (log_RDEP)")
plt.show()

# %%
# 1. Define Target
target = 'log_RDEP'

# 2. Automated Selection: Pick features with correlation > 0.3 (or < -0.3)
# This removes noise like 'X_LOC' or 'Bit Size' automatically
correlations = corr_matrix[target]
features = correlations[abs(correlations) > 0.59].index.drop(target).tolist()

print(f"✅ Selected Predictors based on EDA: {features}")

# 3. Prepare the Clean Dataset (Ground Truth)
# We need rows where ALL selected features + target are present
df_clean = df.copy()
df_clean['log_RDEP'] = np.log10(df_clean['RDEP']) # Create the target
df_clean = df_clean[features + [target]].dropna()


print(f"Final Dataset Size for PoC: {len(df_clean)}")
# Out:
# ✅ Selected Predictors based on EDA: ['RMED', 'RHOB', 'GR', 'NPHI', 'DTC', 'DTS']
# Final Dataset Size for PoC: 10370

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10302 entries, 54 to 10940
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   RMED      10302 non-null  float64
#  1   RHOB      10302 non-null  float64
#  2   GR        10302 non-null  float64
#  3   NPHI      10302 non-null  float64
#  4   DTC       10302 non-null  float64
#  5   DTS       10302 non-null  float64
#  6   log_RDEP  10302 non-null  float64
# dtypes: float64(7)
# memory usage: 901.9 KB

# %%
# Function to create missing values 
def create_missing_data(dataframe, target_col, frac=0.2, random_state=42):
    """
    Randomly removes 'frac' percentage of data from the target_col.
    Returns:
        df_missing: DataFrame with NaNs
        missing_idx: Indices of the missing rows (to verify later)
        true_values: The original values that were removed
    """
    df_missing = dataframe.copy()
    
    # Get a sample of indices to drop
    np.random.seed(random_state)
    n_samples = int(len(dataframe) * frac)
    missing_idx = np.random.choice(dataframe.index, n_samples, replace=False)
    
    # Store the true values before we delete them (for evaluation)
    true_values = dataframe.loc[missing_idx, target_col].values
    
    # Introduce NaN
    df_missing.loc[missing_idx, target_col] = np.nan
    
    print(f"Removed {n_samples} values from '{target_col}' ({frac*100}%).")
    return df_missing, missing_idx, true_values

# %%
# Run the simulation
df_miss, missing_indices, y_true = create_missing_data(df_clean,'log_RDEP', frac=0.2)
# Out:
# Removed 2074 values from 'log_RDEP' (20.0%).

# %%
# --- 3. VISUALIZE THE GAP (Optional but nice) ---
plt.figure(figsize=(12, 3))
plt.plot(df_clean.index[0:200], df_clean['log_RDEP'][0:200], 'k-', label='True Data', alpha=0.3)
plt.plot(df_miss.index[0:200], df_miss['log_RDEP'][0:200], 'b-', label='Observed Data')
plt.title("Visualizing the Artificial Gaps (First 200 rows)")
plt.legend()
plt.show()

# %%
# A. Split into Train (Existing Data) and Test (Missing Data)
train_df = df_miss[df_miss[target].notna()]
test_df = df_miss[df_miss[target].isna()]

X_train = train_df[features]
y_train = train_df[target]
X_test = test_df[features]

# B. Train the Model (Gradient Boosting for Speed/Accuracy)
print("Training Model...")
model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
model.fit(X_train, y_train)

y_pred = model.predict(X_test) # This fills the missing values

y_pred_train = model.predict(X_train) 

residuals = y_train - y_pred_train
sigma_naive = np.std(residuals)
# Out:
# Training Model...

# %%
# Simulation Settings
n_simulations = 100
coverage_factor = 1.64  # Using 1.64 Sigma for a theoretical 90% Interval

mc_predictions = []

print("Running Monte Carlo Simulation...")
for pred in y_pred:
    # Generate 100 outcomes per missing point
    sims = np.random.normal(loc=pred, scale=sigma_naive , size=n_simulations)
    mc_predictions.append(sims)

mc_predictions = np.array(mc_predictions) # Shape: (N_missing, 100)

# Calculate Bounds (5th and 95th percentiles)
lower_bound = np.percentile(mc_predictions, 5, axis=1)
upper_bound = np.percentile(mc_predictions, 95, axis=1)
mc_mean = np.mean(mc_predictions, axis=1)
# Out:
# Running Monte Carlo Simulation...

# %%
# Calculate Coverage
inside_band = (y_true >= lower_bound) & (y_true <= upper_bound)
coverage_score = np.mean(inside_band)

# Plotting a subset (zoom in) to see details
zoom_start, zoom_end = 0, 150

plt.figure(figsize=(14, 6))

# 1. Plot Truth
plt.plot(y_true[zoom_start:zoom_end], 'k', label='Ground Truth', alpha=0.6, linewidth=2)

# 2. Plot Simple ML Prediction
plt.plot(y_pred[zoom_start:zoom_end], 'b--', label='ML Mean Prediction', linewidth=1)

# 3. Plot Monte Carlo Uncertainty Band
plt.fill_between(range(zoom_end - zoom_start), 
                 lower_bound[zoom_start:zoom_end], 
                 upper_bound[zoom_start:zoom_end], 
                 color='green', alpha=0.3, label=f'MCS 90% CI (Coverage={coverage_score:.1%})')

plt.title("Coupling ML with Monte Carlo: Imputation with Uncertainty Quantification")
plt.ylabel("Log10(Resistivity)")
plt.xlabel("Sample Index (Missing Data Points)")
plt.legend()
plt.show()

# %%
# --- REVERTING TO ROBUST PHYSICS ---

# 1. Define the "Clean" Feature List
# We exclude RMED (Leakage Risk) and DTC/DTS (Noise Risk)
robust_features = ['GR', 'RHOB', 'NPHI']

print(f"Testing Robust Features: {robust_features}")

# 2. Re-Train and Evaluate
X_train_rob = train_df[robust_features]
y_train_rob = train_df[target]
X_test_rob = test_df[robust_features]

# Train
model_rob = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
model_rob.fit(X_train_rob, y_train_rob)

# Predict
y_pred_rob = model_rob.predict(X_test_rob)

# Evaluate
rmse_rob = np.sqrt(mean_squared_error(y_true, y_pred_rob))

print(f"✅ RMSE with Robust Features: {rmse_rob:.4f}")
print("(This should be lower/better than the model with DTC/RMED)")
# Out:
# Testing Robust Features: ['GR', 'RHOB', 'NPHI']
# ✅ RMSE with Robust Features: 0.4619
# (This should be lower/better than the model with DTC/RMED)

# %%
# Check how many true values fell inside the 90% bounds
inside_band = (y_true >= lower_bound) & (y_true <= upper_bound)
coverage_prob = np.mean(inside_band)

print(f"Target Coverage: 0.90")
print(f"Actual Coverage: {coverage_prob:.4f}")

if coverage_prob > 0.85:
    print("✅ SUCCESS: The Uncertainty Quantification is well-calibrated!")
else:
    print("⚠️ ADJUSTMENT: The model is slightly over/under confident.")
# Out:
# Target Coverage: 0.90
# Actual Coverage: 0.1477
# ⚠️ ADJUSTMENT: The model is slightly over/under confident.

# %%
from sklearn.model_selection import cross_val_predict

# --- 1. RE-CALCULATE SIGMA (THE RIGOROUS WAY) ---

# Instead of predicting on data we just trained on, we use Cross Validation
# This generates "out-of-sample" predictions for every point in the training set
print("Calculating realistic uncertainty using Cross-Validation...")
y_cv_pred = cross_val_predict(model, X_train, y_train, cv=5, n_jobs=-1)

# Now calculate residuals based on these "honest" predictions
cv_residuals = y_train - y_cv_pred
sigma_calibrated = np.std(cv_residuals)

print(f"Old Sigma (Training): {sigma:.4f}")       # Likely tiny
print(f"New Sigma (Calibrated): {sigma_calibrated:.4f}") # Likely much larger

# --- 2. RERUN MONTE CARLO WITH NEW SIGMA ---
n_simulations = 100
mc_predictions_new = []

for pred in y_pred_mean:
    # Use the NEW sigma_calibrated
    sims = np.random.normal(loc=pred, scale=sigma_calibrated, size=n_simulations)
    mc_predictions_new.append(sims)

mc_predictions_new = np.array(mc_predictions_new)

# --- 3. RE-CALCULATE BOUNDS ---
lower_bound_new = np.percentile(mc_predictions_new, 5, axis=1)
upper_bound_new = np.percentile(mc_predictions_new, 95, axis=1)

# --- 4. CHECK COVERAGE AGAIN ---
inside_band_new = (y_true >= lower_bound_new) & (y_true <= upper_bound_new)
coverage_prob_new = np.mean(inside_band_new)

print(f"New Actual Coverage: {coverage_prob_new:.4f}")

# --- 5. VISUALIZE THE DIFFERENCE ---
plt.figure(figsize=(12, 5))
plt.plot(df_cmplt.index[50:250], df_cmplt['log_RDEP'][50:250], 'k', label='True Data', alpha=0.5)
plt.plot(df_filled.index[50:250], df_filled['log_RDEP'][50:250], 'r--', label='Mean Prediction')

# Plot the NEW Wider Bands
plt.fill_between(zoom_indices, 
                 lower_bound_new[test_mask], 
                 upper_bound_new[test_mask], 
                 color='green', alpha=0.2, label=f'Corrected MCS (Sigma={sigma_calibrated:.2f})')

plt.title(f"Calibrated Uncertainty (Coverage: {coverage_prob_new:.2%})")
plt.legend()
plt.show()
# Out:
# Calculating realistic uncertainty using Cross-Validation...
# Old Sigma (Training): 0.0333
# New Sigma (Calibrated): 0.1921
# New Actual Coverage: 0.5361

# %%
# 1. Calculate the Mean of the 100 simulations for each point
# We take the average across the 100 columns (axis 1)
mc_mean_trace = np.mean(mc_preds_s, axis=1)

# 2. Plotting
plt.figure(figsize=(12, 5))

# A. Plot Ground Truth (Grey)
plt.plot(y_true_simple[:100], 'k', label='True Data', alpha=0.4, linewidth=3)

# B. Plot the Single ML Prediction (Red Line) - The "Deterministic" view
plt.plot(y_pred_s[:100], 'r', label='Single ML Prediction', linewidth=1, alpha=0.6)

# C. Plot the Mean of MC Simulations (Blue Dashed) - The "Probabilistic" Average
plt.plot(mc_mean_trace[:100], 'b--', label='Mean of MC Simulations (N=100)', linewidth=2)

plt.title("Convergence Check: Does the MC Mean match the Prediction?")
plt.xlabel("Index")
plt.ylabel("Log(Resistivity)")
plt.legend()
plt.show()

# 3. Quantitative Check
diff = np.mean(np.abs(y_pred_s - mc_mean_trace))
print(f"Average difference between Single Model and MC Mean: {diff:.5f}")
# Out:
# Average difference between Single Model and MC Mean: 0.02086

# %%
from sklearn.ensemble import HistGradientBoostingRegressor

# --- 1. TRAIN THE NEW MODEL (Gradient Boosting) ---
print("Training Gradient Boosting Model...")
model_gb = HistGradientBoostingRegressor(random_state=42)
model_gb.fit(X_train_s, y_train_s)

# Predict
y_pred_gb = model_gb.predict(X_test_s)

# --- 2. CALIBRATE UNCERTAINTY (Cross-Validation) ---
# We need to find the 'Sigma' for this specific model
print("Calibrating Uncertainty...")
y_cv_pred_gb = cross_val_predict(model_gb, X_train_s, y_train_s, cv=5)
sigma_gb = np.std(y_train_s - y_cv_pred_gb)

print(f"Gradient Boosting Sigma: {sigma_gb:.4f}")

# --- 3. COMPARE PERFORMANCE (RMSE) ---
rmse_gb = np.sqrt(mean_squared_error(y_true_simple, y_pred_gb))

print(f"\n--- BATTLE OF THE MODELS ---")
print(f"Random Forest RMSE:      {rmse_mc:.4f}") # From previous step
print(f"Gradient Boosting RMSE:  {rmse_gb:.4f}")

if rmse_gb < rmse_mc:
    print("🏆 WINNER: Gradient Boosting is more accurate!")
else:
    print("🏆 WINNER: Random Forest is still the king.")

# --- 4. VISUALIZE THE NEW RESULT ---
# Let's see if the bands look tighter or better
k = 1.5
mc_preds_gb = []
for pred in y_pred_gb:
    sims = np.random.normal(loc=pred, scale=sigma_gb * k, size=100)
    mc_preds_gb.append(sims)
mc_preds_gb = np.array(mc_preds_gb)

lower_gb = np.percentile(mc_preds_gb, 5, axis=1)
upper_gb = np.percentile(mc_preds_gb, 95, axis=1)

plt.figure(figsize=(12, 4))
plt.plot(y_true_simple[:100], 'k', label='True Data', alpha=0.5)
plt.plot(y_pred_gb[:100], 'b--', label='GB Prediction', linewidth=1)
plt.fill_between(range(100), lower_gb[:100], upper_gb[:100], color='blue', alpha=0.2, label='GB MCS Bounds')
plt.title(f"Gradient Boosting Imputation (RMSE: {rmse_gb:.4f})")
plt.legend()
plt.show()
# Out:
# Training Gradient Boosting Model...
# Calibrating Uncertainty...
# Gradient Boosting Sigma: 0.1712
#
# --- BATTLE OF THE MODELS ---
# Random Forest RMSE:      0.3193
# Gradient Boosting RMSE:  0.3165
# 🏆 WINNER: Gradient Boosting is more accurate!
